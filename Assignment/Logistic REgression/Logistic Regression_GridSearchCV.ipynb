# %%
#Importing the libraries 
import pandas as pd
import numpy as np

# %%
#Read the Dataset file
dataset=pd.read_csv("CKD.csv")

# %%
#View the Dataset file 
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
#Pre-processed Data
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# 0    137.528754  4.627244  12.518156  ...      False        False       False
# 1    137.528754  4.627244  10.700000  ...       True        False       False
# 2    138.000000  4.400000  12.000000  ...       True        False       False
# 3    138.000000  3.200000   8.100000  ...       True        False       False
# 4    137.528754  4.627244  11.800000  ...       True        False       False
# ..          ...       ...        ...  ...        ...          ...         ...
# 394  139.000000  3.700000  12.500000  ...       True        False       False
# 395  137.528754  4.627244   8.700000  ...       True        False       False
# 396  134.000000  2.700000   9.100000  ...       True        False       False
# 397  142.000000  5.500000   8.500000  ...       True        False       False
# 398  140.000000  5.000000  16.300000  ...       True        False       False
#
#      htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# 0      False   False    False       True    True    False                True
# 1      False   False    False       True   False    False                True
# 2      False   False    False       True   False    False                True
# 3      False   False    False       True   False     True                True
# 4      False   False    False       True   False    False                True
# ..       ...     ...      ...        ...     ...      ...                 ...
# 394    False   False    False       True   False    False                True
# 395     True    True    False       True   False     True                True
# 396     True    True    False      False   False    False                True
# 397     True    True    False       True   False     True                True
# 398    False   False    False       True   False    False               False
#
# [399 rows x 28 columns]

# %%
#Number of classes and counts in the Target column

dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
#List the column names 
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
#Input and output split
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

dependent=dataset[['classification_yes']]

# %%
independent
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  rbc_normal  pc_normal  pcc_present  \
# 0    137.528754  4.627244  12.518156  ...        True      False        False
# 1    137.528754  4.627244  10.700000  ...        True       True        False
# 2    138.000000  4.400000  12.000000  ...        True       True        False
# 3    138.000000  3.200000   8.100000  ...        True       True        False
# 4    137.528754  4.627244  11.800000  ...        True       True        False
# ..          ...       ...        ...  ...         ...        ...          ...
# 394  139.000000  3.700000  12.500000  ...        True       True        False
# 395  137.528754  4.627244   8.700000  ...        True       True        False
# 396  134.000000  2.700000   9.100000  ...        True       True        False
# 397  142.000000  5.500000   8.500000  ...        True       True        False
# 398  140.000000  5.000000  16.300000  ...        True       True        False
#
#      ba_present  htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes
# 0         False    False   False    False       True    True    False
# 1         False    False   False    False       True   False    False
# 2         False    False   False    False       True   False    False
# 3         False    False   False    False       True   False     True
# 4         False    False   False    False       True   False    False
# ..          ...      ...     ...      ...        ...     ...      ...
# 394       False    False   False    False       True   False    False
# 395       False     True    True    False       True   False     True
# 396       False     True    True    False      False   False    False
# 397       False     True    True    False       True   False     True
# 398       False    False   False    False       True   False    False
#
# [399 rows x 27 columns]

# %%
dependent
# Out:
#      classification_yes
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ..                  ...
# 394                True
# 395                True
# 396                True
# 397                True
# 398               False
#
# [399 rows x 1 columns]

# %%
# to display all the column names with few rows

pd.set_option('display.max_columns', None)
print(dataset.head())
# Out:
#    age         bp   al   su         bgr         bu        sc         sod  \
# 0  2.0  76.459948  3.0  0.0  148.112676  57.482105  3.077356  137.528754
# 1  3.0  76.459948  2.0  0.0  148.112676  22.000000  0.700000  137.528754
# 2  4.0  76.459948  1.0  0.0   99.000000  23.000000  0.600000  138.000000
# 3  5.0  76.459948  1.0  0.0  148.112676  16.000000  0.700000  138.000000
# 4  5.0  50.000000  0.0  0.0  148.112676  25.000000  0.600000  137.528754
#
#         pot       hrmo        pcv            wc        rc   sg_b   sg_c  \
# 0  4.627244  12.518156  38.868902   8408.191126  4.705597  False   True
# 1  4.627244  10.700000  34.000000  12300.000000  4.705597  False   True
# 2  4.400000  12.000000  34.000000   8408.191126  4.705597  False  False
# 3  3.200000   8.100000  38.868902   8408.191126  4.705597  False  False
# 4  4.627244  11.800000  36.000000  12400.000000  4.705597  False   True
#
#     sg_d   sg_e  rbc_normal  pc_normal  pcc_present  ba_present  htn_yes  \
# 0  False  False        True      False        False       False    False
# 1  False  False        True       True        False       False    False
# 2  False  False        True       True        False       False    False
# 3   True  False        True       True        False       False    False
# 4  False  False        True       True        False       False    False
#
#    dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# 0   False    False       True    True    False                True
# 1   False    False       True   False    False                True
# 2   False    False       True   False    False                True
# 3   False    False       True   False     True                True
# 4   False    False       True   False    False                True

# %%
# Train-test split 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.3,random_state=0)

# %%
#Data-preprocessing 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
# Model Creation step 
# Hyperparameter tuning using GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

param_grid={'solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
                      'penalty':['l2']}
grid=GridSearchCV(LogisticRegression(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'penalty': ['l2'],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']},
#              scoring='f1_weighted', verbose=3)

# %%
# Performing predictions by passing test data as input


Result=grid.cv_results_
grid_prediction=grid.predict(x_test)

# %%
#Evaluating metrics

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_prediction)

# %%
#print the confusion Matrix
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[45  0]
#  [ 1 74]]

# %%
#classification report
# Evaluation metrics

from sklearn.metrics import classification_report
clf_report=classification_report(y_test, grid_prediction)

# %%
#print the classification report
print("classification report:\n",clf_report)
# Out:
# classification report:
#                precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99        45
#         True       1.00      0.99      0.99        75
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# Evaluation Metrics

from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
# Out:
# 1.0

# %%
# GridsearchCV hyperparameter tuning table 

table=pd.DataFrame.from_dict(Result)

# %%
# view the table 
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_penalty  \
# 0       0.026407      0.007193         0.008413        0.000224            l2
# 1       0.008865      0.002723         0.008459        0.002312            l2
# 2       0.010241      0.002486         0.009188        0.002137            l2
# 3       0.012457      0.001651         0.008484        0.001598            l2
# 4       0.020482      0.002775         0.008742        0.001262            l2
# 5       0.017422      0.001887         0.007974        0.001411            l2
#
#       param_solver                                          params  \
# 0            lbfgs            {'penalty': 'l2', 'solver': 'lbfgs'}
# 1        liblinear        {'penalty': 'l2', 'solver': 'liblinear'}
# 2        newton-cg        {'penalty': 'l2', 'solver': 'newton-cg'}
# 3  newton-cholesky  {'penalty': 'l2', 'solver': 'newton-cholesky'}
# 4              sag              {'penalty': 'l2', 'solver': 'sag'}
# 5             saga             {'penalty': 'l2', 'solver': 'saga'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.982221           1.000000           0.982221           1.000000
# 1           0.964572           0.982221           0.964572           0.964572
# 2           0.982221           1.000000           0.982221           1.000000
# 3           0.982221           1.000000           0.982221           1.000000
# 4           0.982221           0.982221           0.982221           0.982221
# 5           0.964572           0.982221           0.964572           0.982221
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           1.000000         0.992888        0.008710                1
# 1           0.981894         0.971566        0.008567                6
# 2           1.000000         0.992888        0.008710                1
# 3           1.000000         0.992888        0.008710                1
# 4           1.000000         0.985777        0.007112                4
# 5           0.981894         0.975096        0.008594                5

# %%
# Get the inputs from the user and perform Future Predictions

Input_age = float(input("AGE:"))
Input_bp = float(input("Bp:"))
Input_al = float(input("Al:"))
Input_Su = float(input("Su:"))
Input_Bgr = float(input("BGR:"))
Input_Bu = float(input("Bu:"))
Input_Sc = float(input("Sc:"))
Input_Sod = float(input("Sod:"))
Input_Pot = float(input("Pot:"))
Input_hrmo = float(input("hrmo:"))
Input_pcv = float(input("pcv:"))
Input_wc = float(input("Wc:"))
Input_rc = float(input("Rc:"))
Input_sg_b = int(input("SG_B:"))
Input_sg_c = int(input("SG_C:"))
Input_sg_d = int(input("SG_D:"))
Input_sg_e = int(input("SG_E:"))
Input_rbc_normal = int(input("Rbc_normal:"))
Input_pc_normal = int(input("Pc_normal:"))
Input_pcc_present = int(input("Pcc_present:"))
Input_ba_present = int(input("Ba_present:"))
Input_htn = int(input("Htn_yes:"))
Input_dm = int(input("Dm_yes:"))
Input_cad = int(input("Cad_yes:"))
Input_appet = int(input("Appet_yes:"))
Input_pe = int(input("Pe_yes:"))
Input_ane = int(input("Ane_yes:"))
# Out:
# AGE: 6.0
# Bp: 80.459949
# Al: 4.0
# Su: 0.0
# BGR: 149.112676
# Bu: 25.000000
# Sc: 4.077356
# Sod: 139.528755
# Pot: 4.627288
# hrmo: 13.518159
# pcv: 39.868900
# Wc: 8409.191129
# Rc: 5.705599
# SG_B: 1
# SG_C: 1
# SG_D: 0
# SG_E: 0
# Rbc_normal: 1
# Pc_normal: 1
# Pcc_present: 0
# Ba_present: 1
# Htn_yes: 1
# Dm_yes: 0
# Cad_yes: 1
# Appet_yes: 0
# Pe_yes: 1
# Ane_yes: 0

# %%
Future_prediction=grid.predict([[Input_age, Input_bp, Input_al, Input_Su, Input_Bgr, Input_Bu, Input_Sc,  Input_Sod, Input_Pot, Input_hrmo, Input_pcv, 
                                Input_wc, Input_rc,  Input_sg_b, Input_sg_c, Input_sg_d, Input_sg_e, Input_rbc_normal, Input_pc_normal, Input_pcc_present,
                                Input_ba_present, Input_htn, Input_dm, Input_cad, Input_appet, Input_pe, Input_ane]])
print("Chronic Kidney Disease possibility:\n", Future_prediction)
# Out:
# Chronic Kidney Disease possibility:
#  [False]

# %%
#pickle library is used to save the model
#filename is created to save the model created 
#using pickle.dump we are saving the model to a file name -Finalized_model_linear.sav

import pickle
filename="Finalized_model_LogisticRegression.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
#using pickle.We are loading the model to a variable loaded_model

loaded_model=pickle.load(open("Finalized_model_LogisticRegression.sav",'rb'))
result=loaded_model.predict([[Input_age, Input_bp, Input_al, Input_Su, Input_Bgr, Input_Bu, Input_Sc,  Input_Sod, Input_Pot, Input_hrmo, Input_pcv, 
                                Input_wc, Input_rc,  Input_sg_b, Input_sg_c, Input_sg_d, Input_sg_e, Input_rbc_normal, Input_pc_normal, Input_pcc_present,
                                Input_ba_present, Input_htn, Input_dm, Input_cad, Input_appet, Input_pe, Input_ane]])

# %%
#View the Result

print("Chronic Kidney Disease possibility:\n", result)
# Out:
# Chronic Kidney Disease possibility:
#  [False]
